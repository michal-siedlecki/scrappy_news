# %%
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

browser = webdriver.Chrome()

browser.get("https://wiadomosci.onet.pl/politico")
time.sleep(5)


elem = browser.find_element_by_tag_name("body")

no_of_pagedowns = 300

while no_of_pagedowns:
    elem.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.8)
    no_of_pagedowns-=1

headers = browser.find_elements_by_class_name("boxTitle")
for header in headers:
    header = header.find_element_by_class_name('title')

print(len(headers))
# Out:
# 1004

# %%
for header in headers[:10]:
    print(header.text)
# Out:
# Ostatni wielki bój Kaczyńskiego [KOMENTARZ]
# Jan Cienski
# Boris Johnson przedstawia propozycje w sprawie brexitu, ale Unia się krzywi
# Emilio Casalicchio; Charlie Cooper
# Wojciechowski dalej w grze – teraz odpowie na pisemne pytania z europarlamentu
# Michał Broniatowski
# Impeachment prezydenta USA coraz realniejszy, ale Trump nazywa to "brednią"
# Michał Broniatowski
# Polityczny podział w kraju dotyka nawet rodzin - jak Polskę widać z perspektywy Brukseli
# Zosia Wanat
# Janusz Wojciechowski, kandydat na unijnego komisarza ds. rolnictwa staje dziś do egzaminu w europarlamencie
# Michał Broniatowski
# Jak będą wyglądać przesłuchania kandydatów na unijnych komisarzy w Parlamencie Europejskim?
# Maia de la Baume
# Duch terrorystycznej organizacji ETA wciąż żyje w hiszpańskiej polityce
# Guy Hedgecoe
# Z powodu brexitu Bruksela traci wiarę w Wielką Brytanię
# Jacopo Barigazzi; David M. Herszenhorn
# Europosłanka Sylwia Spurek walczy o wegańskie jedzenie w unijnych stołówkach
# ...

# %%
with open('politics-onet.txt', 'w') as f:
    for x in politics:
        f.write(x)

# %%
with open('politics-onet.txt', 'w') as f:
    for x in politics:
        f.write(x)

# %%
import requests
from flask import Flask, render_template
from bs4 import BeautifulSoup

num = 2
politico_tvn = []

for _ in range(90):
    url = 'https://www.tvn24.pl/wiadomosci-ze-swiata,2/{}'.format(num)
    time.sleep(0.2)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    small_headers = soup.find_all(class_='size28')
    large_headers = soup.find_all(class_='size36')
    xlarge_headers = soup.find_all(class_='size36')
    for header in small_headers:
        politico_tvn.append(header.text)
    for header in large_headers:
        politico_tvn.append(header.text)
    for header in xlarge_headers:
        politico_tvn.append(header.text)
    num +=1
    
print(len(politico_tvn))
# Out:
# 937

# %%
with open('politics-tvn.txt', 'a') as f:
    f.write('\n')
    for x in politico_tvn:
        f.write(x)
        f.write('\n')
