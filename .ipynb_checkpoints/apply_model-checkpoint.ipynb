# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
from stempel import StempelStemmer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
import pickle

f = open('finalized_model.sav', 'rb')
model = pickle.load(f)
f.close()

sport = pd.read_csv(r"headers_corp.csv",encoding='utf-8').iloc[1000:1010]
nonsport = pd.read_csv(r"headers_corp.csv",encoding='utf-8').iloc[-110:-100]
Corpus = pd.concat([sport,nonsport]).reset_index(drop=True)

samples = [x for x in Corpus['text']]
print(samples)
# Out:
# ['Bartosz Kurek wraca do zdrowia szybciej niż przewidywano!', 'Chłopiec od podawania piłek pomógł wygrać Liverpoolowi. Wszystko przez jeden szczegół', 'Rosyjscy piłkarze skazani na kolonię karną', 'Liverpool w finale LM. Reuters: Pozostawili Messiego i Barcelonę w stanie stresu pourazowego', 'Liverpool w finale LM po rozgromieniu Barcelony. Klopp: "Nie wiem jak chłopaki tego dokonali"', 'Sensacja w Lidze Mistrzów. Liverpool pokonał Barcelonę 4:0 i awansował do finału', 'Krzyk tenisistów na korcie może zmylić przeciwnika', 'Szczypiorniści PGE Vive Kielce poznali rywala w półfinale Ligi Mistrzów', 'Tiger Woods odznaczony przez Trumpa Prezydenckim Medalem Wolności', 'Liga Mistrzów: FC Barcelona blisko finału przed rewanżem', 'Ogień pytań: Najmniej przydatne umiejętności gwiazd. Edyta Herbuś was zaskoczy!', 'Pogoda dla Polski - 18.08', 'Ślub Andrzeja Wrony i Zofii Zborowskiej był wydarzeniem tygodnia. Pobrała się też para która od lat budzi emocje', 'Joanna Kluzik-Rostkowska w "Onet Rano".: czy za kłamstwa ponosi się konsekwencje?', 'Nowe fakty w sprawie Kraski. Publikujemy nagranie z monitoringu', 'Bulwersujące nagranie chrztu w Rosji. Pop szarpał i potrząsał niemowlakiem', 'Podsumowanie tygodnia. Najważniejsze wydarzenia w Polsce i na świecie', 'Jak dobrze prowadzić nowoczesny biznes?', 'Poszukiwania Piotra Woźniaka-Staraka. Do akcji włącza się WOT', 'Nowe szczegóły akcji ratowania grotołazów']

# %%
samples = [word_tokenize(entry) for entry in samples]

# %%
Tfidf_vect = TfidfVectorizer(max_features=1000)
Tfidf_vect.fit(samples)
my_test = Tfidf_vect.transform(samples)
print(my_test)
print(type(my_test))

predictions = model.predict(my_test)

for tup in zip(samples,predictions):
    print(tup[0])
    print(tup[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-f3a794b98bdb> in <module>()
#       1 Tfidf_vect = TfidfVectorizer(max_features=1000)
# ----> 2 Tfidf_vect.fit(samples)
#       3 my_test = Tfidf_vect.transform(samples)
#       4 print(my_test)
#       5 print(type(my_test))
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit(self, raw_documents, y)
#    1359         self : TfidfVectorizer
#    1360         """
# -> 1361         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1362         self._tfidf.fit(X)
#    1363         return self
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(doc)
#     264
#     265             return lambda doc: self._word_ngrams(
# --> 266                 tokenize(preprocess(self.decode(doc))), stop_words)
#     267
#     268         else:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(x)
#     230
#     231         if self.lowercase:
# --> 232             return lambda x: strip_accents(x.lower())
#     233         else:
#     234             return strip_accents
#
# AttributeError: 'list' object has no attribute 'lower'
