# %%
import requests
from bs4 import BeautifulSoup


news_num = 7


class Feed:
    def __init__(self, name, url, selector):
        self.name = name
        self.url = url
        self.selector = selector

    def get_headers(self):
        page = requests.get(self.url)
        soup = BeautifulSoup(page.content, 'html.parser')
#         news = soup.find_all(class_=self.selector)
        art = soup.ul.text

        return art
    
#     [x.next for x in news[1:(news_num - 1)]]
        
        
   


onet = Feed('Onet', 'https://www.onet.pl/', "title")




print(type(onet.get_headers()))
print(onet.get_headers().strip())
# Out:
# <class 'str'>
# Sympatia
#
#
#
#
#
#
#
#
#
#
#
#
# Zakupy
#
#
#
#
#
#
#
#
#
#
#
#
# Gry
#
#
#
#
#
#
#
#
#
#
#
#
# Vod
#
#
#
#
# nowe
#
#
#
#
#
#
#
#
# Znajdź pracę
#
#
#
#
#
#
#
#
#
#
#
#
#
# E-MAIL
