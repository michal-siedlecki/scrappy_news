# %% [markdown]
# # import bags of words

# %%
import requests, re
from bs4 import BeautifulSoup


with open('stopwords/polish.stopwords.txt') as f:
    polish_sw = [word.replace('\n','') for word in f.readlines()]
    

class Feed:
    def __init__(self, name, url):
        self.name = name
        self.url = url
    
    def makeSoup(self):
        page = requests.get(self.url)
        soup = BeautifulSoup(page.content, 'html.parser')
        return soup
    
    
    def getHeadersSport(self):
        
        soup = self.makeSoup()
        
        if self.name == 'Onet':
            divs = soup.find_all(class_="sectionLine sectionLineMax")
            articles_sets = [div.find_all('a') for div in divs]
            onet_dic = {}
            for articles in articles_sets:
                for article in articles:                    
                    onet_dic[article.find(class_="title").text] = article.attrs.get('href')
            return onet_dic   
    

    def getHeaders(self):
        
        soup = self.makeSoup()
        
        if self.name == 'Onet':
            divs = soup.find_all(class_="boxContent")
            articles_sets = [div.find_all('a') for div in divs]
            onet_dic = {'name' : self.name}     
            for articles in articles_sets:
                for article in articles:                    
                    onet_dic[article.find(class_="title").text] = article.attrs.get('href')
            return onet_dic   
        
        
        if self.name == 'Wirtualna Polska':
            divs = soup.find_all(class_="sc-1fu2hk8-0 jIlknD")
            articles_sets = [div.find_all('a') for div in divs]
            wp_dic = {'name' : self.name}         
            for articles in articles_sets:
                for article in articles:                
                    if len(wp_dic) <= news_num+1:
                        try:
                            wp_dic[article.find_all('div')[1].text] = article.attrs.get('href')
                        except IndexError:
                            wp_dic[article.find('div').text] = article.attrs.get('href')
                    else:
                        return wp_dic
                    
        
        if self.name == 'W Polityce':
            divs = soup.find_all(class_="nu-lead-articles") + soup.find_all(class_="nu-tile-container nu-main-col--5")
            articles_sets = [div.find_all('a') for div in divs]
            wpolityce_dic = {'name' : self.name}
            for articles in articles_sets:
                for article in articles:
                    if len(wpolityce_dic) <= news_num+1:
                        wpolityce_dic[article.find(class_="short-title").text] = str(self.url[:-1])+str(article.attrs.get('href'))
                    else:
                        return wpolityce_dic

        
onet = Feed('Onet', 'https://www.onet.pl/')
wp = Feed('Wirtualna Polska', 'https://www.wp.pl/')
wpolityce = Feed('W Polityce', 'https://wpolityce.pl/')

feed_list = [onet, wp, wpolityce]




def writeSport():
    
    with open('onet_sport.txt', 'a+') as f:
        existing_titles = f.readlines()
        for title, link in onet.getHeadersSport().items():
            if re.search(r'.sport.', link):
                if title not in existing_titles:
                    f.write(title+'\n')

def writePolitics():
    a = 0
    with open('onet_polityka.txt', 'a+') as f:
        existing_titles = f.readlines()
        for title, link in onet.getHeaders().items():
            if a<=12:
                title = title.strip()
                if title not in existing_titles:
                    if title != 'name':
                        f.write(title+'\n')
                    
writeSport()

# %% [markdown]
# count TfIdf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd

with open('stopwords/polish.stopwords.txt') as f:
    polish_sw = [word.replace('\n','') for word in f.readlines()]

    
with open('onet_polityka.txt') as f:
    corpus = f.read().split('\n')[:-1]
    
tfidf = TfidfVectorizer()
response = tfidf.fit_transform(corpus)
feature_names = tfidf.get_feature_names()

for col in response.nonzero()[1]:
    print (feature_names[col], ' - ', response[0, col])
# Out:
# mołotow  -  0.325746009544585
# najwyższe  -  0.0
# są  -  0.0
# gdzie  -  0.0
# polsce  -  0.0
# nie  -  0.0
# powody  -  0.0
# oto  -  0.0
# biznes  -  0.0
# czysty  -  0.0
# trumpa  -  0.0
# pomysł  -  0.0
# lincolna  -  0.0
# już  -  0.0
# grenlandię  -  0.0
# kupić  -  0.0
# chciały  -  0.0
# za  -  0.0
# to  -  0.0
# usa  -  0.0
# tankowca  -  0.0
# irańskiego  -  0.0
# przejęcie  -  0.0
# nakazał  -  0.0
# sąd  -  0.0
# usa  -  0.0
# komercyjną  -  0.0
# rakietę  -  0.0
# pierwszą  -  0.0
# kosmos  -  0.0
# wystrzeliły  -  0.0
# chiny  -  0.0
# karną  -  0.0
# kolonię  -  0.0
# skazany  -  0.0
# huty  -  0.0
# polskiej  -  0.0
# nadzorczej  -  0.0
# rady  -  0.0
# członek  -  0.0
# na  -  0.0
# czarneckiego  -  0.0
# leszka  -  0.0
# bank  -  0.0
# bierze  -  0.0
# knf  -  0.0
# za  -  0.0
# się  -  0.0
# plan  -  0.0
# śmiały  -  0.0
# 2045  -  0.0
# korea  -  0.0
# zjednoczona  -  0.0
# jest  -  0.0
# do  -  0.21214578806097553
# komentarz  -  0.0
# przyszłości  -  0.0
# decyduje  -  0.0
# hongkong  -  0.0
# czasów  -  0.0
# naszych  -  0.0
# rewolucja  -  0.0
# sklepu  -  0.0
# rodzaj  -  0.0
# nowy  -  0.0
# uruchomiła  -  0.0
# biedronka  -  0.0
# smartfonach  -  0.0
# kas  -  0.0
# chce  -  0.0
# finansów  -  0.0
# resort  -  0.0
# wieżę  -  0.0
# dol  -  0.0
# mln  -  0.0
# 110  -  0.0
# wpompował  -  0.0
# przyszłości  -  0.0
# bank  -  0.0
# drogach  -  0.0
# towary  -  0.0
# przewożą  -  0.0
# tiry  -  0.0
# autonomiczne  -  0.0
# już  -  0.0
# po  -  0.0
# dzieci  -  0.0
# ulgi  -  0.0
# mniej  -  0.0
# coraz  -  0.0
# rozliczają  -  0.0
# polacy  -  0.0
# na  -  0.0
# powody  -  0.0
# oto  -  0.0
# biznes  -  0.0
# czysty  -  0.0
# trumpa  -  0.0
# pomysł  -  0.0
# lincolna  -  0.0
# już  -  0.0
# grenlandię  -  0.0
# kupić  -  0.0
# chciały  -  0.0
# za  -  0.0
# to  -  0.0
# usa  -  0.0
# dane  -  0.0
# najnowsze  -  0.0
# podał  -  0.0
# najmniej  -  0.0
# najwięcej  -  0.0
# zarabia  -  0.0
# miastach  -  0.0
# których  -  0.0
# gus  -  0.0
# się  -  0.0
# cpk  -  0.0
# dla  -  0.0
# wzorem  -  0.0
# być  -  0.0
# ma  -  0.0
# europie  -  0.0
# najlepsze  -  0.0
# za  -  0.0
# jest  -  0.0
# uznawane  -  0.0
# lotnisko  -  0.0
# to  -  0.0
# komentarz  -  0.0
# przyszłości  -  0.0
# decyduje  -  0.0
# hongkong  -  0.0
# czasów  -  0.0
# naszych  -  0.0
# rewolucja  -  0.0
# publicznych  -  0.0
# ciężarówki  -  0.0
# drogach  -  0.0
# towary  -  0.0
# przewożą  -  0.0
# autonomiczne  -  0.0
# już  -  0.0
# po  -  0.0
# handlowej  -  0.0
# wojny  -  0.0
# mimo  -  0.0
# wyniki  -  0.0
# mocne  -  0.0
# pokazał  -  0.0
# walmart  -  0.0
# zjazd  -  0.0
# ostry  -  0.0
# zaliczył  -  0.0
# razu  -  0.0
# od  -  0.0
# giganta  -  0.0
# kurs  -  0.0
# oszustwo  -  0.0
# oskarżone  -  0.0
# ge  -  0.0
# telefonu  -  0.0
# składanego  -  0.0
# premierę  -  0.0
# przekłada  -  0.0
# ponownie  -  0.0
# huawei  -  0.0
# relacja  -  0.0
# zdjęcia  -  0.0
# roztańczeni  -  0.0
# piękni  -  0.0
# młodzi  -  0.0
# festival  -  0.0
# live  -  0.0
# kraków  -  0.0
# 2019  -  0.0
# szpaka  -  0.0
# ekstrawagancja  -  0.0
# rodowicz  -  0.0
# owacje  -  0.0
# młynkową  -  0.0
# brathanków  -  0.0
# występ  -  0.0
# lat  -  0.0
# 16  -  0.0
# pierwszy  -  0.0
# od  -  0.0
# dla  -  0.0
# grabowskiego  -  0.0
# krytykę  -  0.0
# odpowiada  -  0.0
# zelnik  -  0.0
# na  -  0.0
# trojanowskiej  -  0.0
# kamp  -  0.0
# koncerty  -  0.0
# niezwykłe  -  0.0
# od  -  0.0
# do  -  0.21214578806097553
# polskę  -  0.0
# odwiedzą  -  0.0
# zniewolonej  -  0.0
# gwiazdy  -  0.0
# synowe  -  0.0
# teściowe  -  0.0
# programu  -  0.0
# premiery  -  0.0
# datę  -  0.0
# znamy  -  0.0
# stanach  -  0.0
# siłowni  -  0.0
# wyrzucony  -  0.0
# nergal  -  0.0
# wieki  -  0.0
# trwał  -  0.0
# żydów  -  0.0
# nienawiści  -  0.0
# umysły  -  0.0
# polskie  -  0.0
# katolicki  -  0.0
# kościół  -  0.0
# przez  -  0.0
# wtłaczania  -  0.0
# proces  -  0.0
# do  -  0.21214578806097553
# dlaczego  -  0.0
# tłumaczy  -  0.0
# kościoła  -  0.0
# odchodzi  -  0.0
# margaret  -  0.0
# black  -  0.0
# joe  -  0.0
# przekręt  -  0.0
# kupują  -  0.0
# najchętniej  -  0.0
# modele  -  0.0
# które  -  0.0
# telewizorów  -  0.0
# najpopularniejszych  -  0.0
# ranking  -  0.0
# wielki  -  0.0
# polacy  -  0.0
# wskazówki  -  0.0
# porady  -  0.0
# triki  -  0.0
# gimp  -  0.0
# najlepsze  -  0.0
# głosowanie  -  0.0
# trwa  -  0.0
# złe  -  0.0
# mikrotransakcje  -  0.0
# czy  -  0.0
# są  -  0.0
# wielkie  -  0.0
# tv  -  0.0
# własny  -  0.0
# szykuje  -  0.0
# smartfonów  -  0.0
# producent  -  0.0
# znany  -  0.0
# sklepach  -  0.0
# polskich  -  0.0
# action  -  0.0
# one  -  0.0
# motorola  -  0.0
# już  -  0.0
# ai  -  0.0
# funkcją  -  0.0
# tani  -  0.0
# qe65q60r  -  0.0
# qled  -  0.0
# samsung  -  0.0
# test  -  0.0
# tv  -  0.0
# telewizory  -  0.0
# ekstrawagancja  -  0.0
# rodowicz  -  0.0
# owacje  -  0.0
# młynkową  -  0.0
# brathanków  -  0.0
# występ  -  0.0
# lat  -  0.0
# 16  -  0.0
# pierwszy  -  0.0
# od  -  0.0
# dla  -  0.0
# grabowskiego  -  0.0
# krytykę  -  0.0
# odpowiada  -  0.0
# zelnik  -  0.0
# na  -  0.0
# polskę  -  0.0
# odwiedzą  -  0.0
# zniewolonej  -  0.0
# gwiazdy  -  0.0
# synowe  -  0.0
# teściowe  -  0.0
# programu  -  0.0
# premiery  -  0.0
# datę  -  0.0
# znamy  -  0.0
# stanach  -  0.0
# siłowni  -  0.0
# wyrzucony  -  0.0
# nergal  -  0.0
# black  -  0.0
# joe  -  0.0
# przekręt  -  0.0
# kupują  -  0.0
# najchętniej  -  0.0
# modele  -  0.0
# które  -  0.0
# telewizorów  -  0.0
# najpopularniejszych  -  0.0
# ranking  -  0.0
# wielki  -  0.0
# polacy  -  0.0
# wskazówki  -  0.0
# porady  -  0.0
# triki  -  0.0
# gimp  -  0.0
# najlepsze  -  0.0
# głosowanie  -  0.0
# trwa  -  0.0
# złe  -  0.0
# mikrotransakcje  -  0.0
# czy  -  0.0
# są  -  0.0
# wielkie  -  0.0
# tv  -  0.0
# własny  -  0.0
# szykuje  -  0.0
# smartfonów  -  0.0
# producent  -  0.0
# znany  -  0.0
# sklepach  -  0.0
# polskich  -  0.0
# action  -  0.0
# one  -  0.0
# motorola  -  0.0
# już  -  0.0
# ai  -  0.0
# funkcją  -  0.0
# tani  -  0.0
# qe65q60r  -  0.0
# qled  -  0.0
# samsung  -  0.0
# test  -  0.0
# tv  -  0.0
# telewizory  -  0.0
# chińskie  -  0.0
# tanie  -  0.0
# kupować  -  0.0
# warto  -  0.0
# czy  -  0.0
# 11  -  0.0
# ów  -  0.0
# iphone  -  0.0
# ujawnia  -  0.0
# apple  -  0.0
# premiery  -  0.0
# datę  -  0.0
# ps4  -  0.0
# gamepada  -  0.0
# wersję  -  0.0
# nową  -  0.0
# zapowiada  -  0.0
# sony  -  0.0
# do  -  0.21214578806097553
# komórkowy  -  0.0
# telefon  -  0.0
# można  -  0.0
# tanio  -  0.0
# kupić  -  0.0
# jak  -  0.0
# aktualizacji  -  0.0
# problemem  -  0.0
# poważnym  -  0.0
# 10  -  0.0
# windows  -  0.0
# po  -  0.0
# wybór  -  0.0
# nasz  -  0.0
# lecia  -  0.0
# 25  -  0.0
# najgorszych  -  0.0
# 20  -  0.0
# aut  -  0.0
# oto  -  0.0
# niemiec  -  0.0
# kampery  -  0.0
# luksusowe  -  0.0
# kołach  -  0.0
# pałace  -  0.0
# na  -  0.0
# je  -  0.0
# ręki  -  0.0
# drugiej  -  0.0
# sedany  -  0.0
# niedrogie  -  0.0
# warto  -  0.0
# kupić  -  0.0
# ryzykujesz  -  0.0
# sporo  -  0.0
# rezerwie  -  0.0
# długo  -  0.0
# jeździsz  -  0.0
# na  -  0.0
# wydatków  -  0.0
# dużych  -  0.0
# spodziewaj  -  0.0
# volvo  -  0.0
# kobiety  -  0.0
# są  -  0.0
# na  -  0.0
# po  -  0.0
# nie  -  0.0
# zaskoczy  -  0.0
# was  -  0.0
# herbuś  -  0.0
# edyta  -  0.0
# gwiazd  -  0.0
# umiejętności  -  0.0
# przydatne  -  0.0
# pytań  -  0.0
# ogień  -  0.0
# najmniej  -  0.0
# 08  -  0.0
# 18  -  0.0
# pogoda  -  0.0
# dla  -  0.0
# polski  -  0.0
# emocje  -  0.0
# budzi  -  0.0
# która  -  0.0
# para  -  0.0
# też  -  0.0
# pobrała  -  0.0
# tygodnia  -  0.0
# wydarzeniem  -  0.0
# był  -  0.0
# zborowskiej  -  0.0
# zofii  -  0.0
# wrony  -  0.0
# andrzeja  -  0.0
# ślub  -  0.0
# lat  -  0.0
# od  -  0.0
# się  -  0.0
# konsekwencje  -  0.0
# ponosi  -  0.0
# kłamstwa  -  0.0
# rano  -  0.0
# onet  -  0.0
# rostkowska  -  0.0
# kluzik  -  0.0
# joanna  -  0.0
# czy  -  0.0
# za  -  0.0
# się  -  0.0
# monitoringu  -  0.0
# publikujemy  -  0.0
# kraski  -  0.0
# sprawie  -  0.0
# fakty  -  0.0
# nowe  -  0.0
# nagranie  -  0.0
# niemowlakiem  -  0.0
# potrząsał  -  0.0
# szarpał  -  0.0
# pop  -  0.0
# rosji  -  0.0
# chrztu  -  0.0
# nagranie  -  0.0
# bulwersujące  -  0.0
# wydarzenia  -  0.0
# najważniejsze  -  0.0
# podsumowanie  -  0.0
# tygodnia  -  0.0
# świecie  -  0.0
# polsce  -  0.0
# na  -  0.0
# nowoczesny  -  0.0
# prowadzić  -  0.0
# dobrze  -  0.0
# biznes  -  0.0
# jak  -  0.0

# %%
with open('stopwords/polish.stopwords.txt') as f:
    polish_sw = [word.replace('\n','') for word in f.readlines()]

    
with open('onet_sport.txt') as f:
    corpus = f.read().split('\n')[:-1]
    

set_list = []  
dic_list = []
word_set = set()

for line in corpus:
    line = set([word.lower().replace("\"","") for word in line.split(" ") if word.lower() not in polish_sw])
    set_list.append(line)


for text in set_list:
    for word in text:
        word_set.add(word)

for index in range(len(set_list)):
    dic_list.append(dict.fromkeys(word_set, 0))
    
    

for i in range(len(dic_list)):
    for word in set_list[i]:
        dic_list[i][word] += 1

        
def computeTF(wordDict, bow):
    tfDict = {}
    bowCount = len(bow)
    for word, count in wordDict.items():
        tfDict[word] = count/float(bowCount)
    return tfDict

def computeIDF(docList):
    import math
    idfDict = {}
    N = len(docList)
    
    idfDict = dict.fromkeys(docList[0].keys(), 0)
    for doc in docList:
        for word, val in doc.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log10(N / float(val))
        
    return idfDict

def computeTFIDF(tfBow, idfs):
    tfidf = {}
    for word, val in tfBow.items():
        tfidf[word] = val*idfs[word]
    return tfidf

tfs = []
idfs = computeIDF(dic_list)


for i in range(len(dic_list)):
    tf = computeTF(dic_list[i], set_list[i])
    tfs.append(tf)
    
tfidfs = [computeTFIDF(tf, idfs) for tf in tfs]   

pd.DataFrame(tfidfs)
