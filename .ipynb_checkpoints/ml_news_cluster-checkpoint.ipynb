# %%
from stop_words import get_stop_words

# 

sentence = 'Siły Zbrojne RP, czyli armia nadająca się na defilady przed wyborami'

stop_words = get_stop_words('pl')

tokens = list(x for x in sentence.split() if x not in stop_words)
# Out:
# ['Siły', 'Zbrojne', 'RP,', 'czyli', 'armia', 'nadająca', 'defilady', 'wyborami']
