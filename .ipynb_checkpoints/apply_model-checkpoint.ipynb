# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
# from nltk.stem import WordNetLemmatizer
from stempel import StempelStemmer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
import pickle

f = open('finalized_model.sav', 'rb')
model = pickle.load(f)
f.close()
# Out:
# C:\Users\Komputer\Anaconda3\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.19.2 when using version 0.21.3. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
sport = pd.read_csv(r"headers_corp.csv",encoding='utf-8').loc[1000:1010]['text'].iloc[0]
sport
# Out:
# 'Bartosz Kurek wraca do zdrowia szybciej niż przewidywano!'

# %%
nonsport = pd.read_csv(r"headers_corp.csv",encoding='utf-8').iloc[-110:-100]['text'].iloc[0]
nonsport
# Out:
# 'Ogień pytań: Najmniej przydatne umiejętności gwiazd. Edyta Herbuś was zaskoczy!'

# %%
sportTokenized = word_tokenize(sport)
nonsportTokenized = word_tokenize(nonsport)

# %%
Tfidf_vect = TfidfVectorizer(max_features=1000)

# %%
Tfidf_vect.fit(sportTokenized)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=1000,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
my_test = Tfidf_vect.transform(sportTokenized)
my_test
# Out:
# <9x8 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8 stored elements in Compressed Sparse Row format>

# %%
predictions = model.predict(my_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-b7ae8bb79182> in <module>
# ----> 1 predictions = model.predict(my_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in predict(self, X)
#      63             Predicted target values for X
#      64         """
# ---> 65         jll = self._joint_log_likelihood(X)
#      66         return self.classes_[np.argmax(jll, axis=1)]
#      67
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in _joint_log_likelihood(self, X)
#     735
#     736         X = check_array(X, accept_sparse='csr')
# --> 737         return (safe_sparse_dot(X, self.feature_log_prob_.T) +
#     738                 self.class_log_prior_)
#     739
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     135     """
#     136     if sparse.issparse(a) or sparse.issparse(b):
# ...
